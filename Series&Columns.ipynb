# %%
import pandas as pd 
houses = pd.read_csv("data/kc_house_data.csv")
titanic  = pd.read_csv("data/titanic.csv")
netflix = pd.read_csv("data/netflix_titles.csv", sep = "|", index_col=0)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.name
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['name']# another way to see the columns of the data sets
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %% [markdown]
# Which to use . or [''] ,here the titanic['name']is the better way cause sometimes there are the spaces in the columns name which cannot be accessed using the dot notation.

# %%
houses.price.sum()
# Out:
# 11672925008.0

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
titanic.size
# Out:
# 18326

# %%
mins = houses.min(numeric_only=True)

# %%
type(mins)
# Out:
# pandas.core.series.Series

# %%
mins
# Out:
# id               1.000102e+06
# price            7.500000e+04
# bedrooms         0.000000e+00
# bathrooms        0.000000e+00
# sqft_living      2.900000e+02
# sqft_lot         5.200000e+02
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        1.000000e+00
# grade            1.000000e+00
# sqft_above       2.900000e+02
# sqft_basement    0.000000e+00
# yr_built         1.900000e+03
# yr_renovated     0.000000e+00
# zipcode          9.800100e+04
# lat              4.715590e+01
# long            -1.225190e+02
# sqft_living15    3.990000e+02
# sqft_lot15       6.510000e+02
# dtype: float64

# %%
 mins.head(10)
# Out:
# id             1000102.0
# price            75000.0
# bedrooms             0.0
# bathrooms            0.0
# sqft_living        290.0
# sqft_lot           520.0
# floors               1.0
# waterfront           0.0
# view                 0.0
# condition            1.0
# dtype: float64

# %% [markdown]
# mins.describe()

# %%
mins.describe()
# Out:
# count    2.000000e+01
# mean     5.885403e+04
# std      2.231546e+05
# min     -1.225190e+02
# 25%      0.000000e+00
# 50%      2.407795e+01
# 75%      5.527500e+02
# max      1.000102e+06
# dtype: float64

# %%
houses["price"].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
netflix["rating"].describe()
# Out:
# count      8803
# unique       17
# top       TV-MA
# freq       3207
# Name: rating, dtype: object

# %%
mins.nunique()
# Out:
# 12

# %%
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix.rating.nunique()
# Out:
# 17

# %%
houses.zipcode.nunique()
# Out:
# 70

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
netflix.rating.nunique()# by default the NaN values are not counted but we can make it count the NaN
# Out:
# 17

# %%
netflix.rating.nunique(dropna=False)
# Out:
# 18

# %%
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
houses.price.nlargest()
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# Name: price, dtype: float64

# %%
houses.price.nsmallest()
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# Name: price, dtype: float64

# %%
# also the dataframe have the same operation for the nlargest and nsmallest 
houses.nlargest(10, ["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses.price.nlargest(10)
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# 1315    5300000.0
# 1164    5110800.0
# 8092    4668000.0
# 2626    4500000.0
# 8638    4489000.0
# Name: price, dtype: float64

# %%
houses.nlargest(10,["bedrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nlargest(10,["bedrooms", "bathrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
#Accessing the multiple columns in the data frame 
n_data = netflix[['title', 'director']].head()

# %%
type(n_data)# obviously its a dataframe cause its not a 1_D
# Out:
# pandas.core.frame.DataFrame

# %%
id(houses)
# Out:
# 1412816808224

# %%
id(n_data)#different memory location
# Out:
# 1412840950560

# %%
houses.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
netflix.director.value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
houses[['bedrooms', 'bathrooms']].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
#                        ...
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Length: 144, dtype: int64

# %%
type(houses[['bedrooms', 'bathrooms']].value_counts())# interesting 
'''
Here it is a series and the bedrooms and bathrooms are the indices and the value are beside those indices 
'''
# Out:
# '\nHere it is a series and the bedrooms and bathrooms are the indices and the value are beside those indices \n'

# %% [markdown]
# # Some basic Plotting

# %%
houses.bedrooms.plot()
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='bedrooms'>
