# %%
import pandas as pd 
titanic = pd.read_csv("data/titanic.csv")
houses = pd.read_csv("data/kc_house_data.csv")
netflix = pd.read_csv("data/netflix_titles.csv", sep = "|")

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
## Geting the data of the people who are older than 20
titanic[titanic['age']>'20' ].sort_index()
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# ...      ...       ...                                              ...
# 1303       3         0                            Yousseff, Mr. Gerious
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["age"]>'20'# what this gives is the series aata which is bolean in value and index (obviously cause Series datasets hhave index assoicated with it )
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: age, Length: 1309, dtype: bool

# %%
test = pd.Series([True, False, False])

# %%
test
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
testdataframe = titanic.loc[0:2]

# %%
testdataframe
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
# 2       1         0    Allison, Miss. Helen Loraine  female       2      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
# 2      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
testdataframe[test]
'''
What this does is that there is True and False associated with the index, so those indices whose value is associated with true 
is printed while those rows of whose indices are associated with false is ignored.
''';

# %%
#okay what this does is that titanic['survived']==0 gives the series data with the values True and False
# and the Indices with associated with True is given out which is the column having survived =0 
titanic[titanic['survived']==0]
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket     fare    cabin embarked boat  \
# ...

# %%
# the infamous between method 
titanic['age'].between('39', '45').value_counts()
# Out:
# False    1189
# True      120
# Name: age, dtype: int64

# %%
titanic[titanic['age'].between('39', '45')]
# Out:
#       pclass  survived                                             name  \
# 7          1         0                           Andrews, Mr. Thomas Jr
# 23         1         1                            Bidois, Miss. Rosalie
# 30         1         0                     Blackwell, Mr. Stephen Weart
# 31         1         1                                 Blank, Mr. Henry
# 34         1         0                         Borebank, Mr. John James
# ...      ...       ...                                              ...
# 1210       3         0                               Skoog, Mr. Wilhelm
# 1211       3         0  Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 1233       3         1                        Sundman, Mr. Johan Julian
# 1252       3         0                        Torber, Mr. Ernst William
# 1264       3         0                  van Billiard, Mr. Austin Blyler
#
#          sex   age  sibsp  parch             ticket     fare cabin embarked  \
# ...

# %% [markdown]
# isin method?

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
countries = ["India", "Japan", "South Korea"]

# %%
netflix[netflix["country"].isin(countries)]# same as above the netflix['country'].isin(contries) return a bool value with indices
# Out:
#       Unnamed: 0 show_id     type  \
# 4              4      s5  TV Show
# 24            24     s25    Movie
# 39            39     s40  TV Show
# 50            50     s51  TV Show
# 51            51     s52    Movie
# ...          ...     ...      ...
# 8773        8773   s8774    Movie
# 8775        8775   s8776  TV Show
# 8798        8798   s8799    Movie
# 8799        8799   s8800    Movie
# 8806        8806   s8807    Movie
#
#                                                   title  \
# 4                                          Kota Factory
# 24                                                Jeans
# 39                                         Chhota Bheem
# 50                                        Dharmakshetra
# 51    InuYasha the Movie 2: The Castle Beyond the Lo...
# ...                                                 ...
# 8773                                Yanda Kartavya Aahe
# 8775                                    Yeh Meri Family
# ...

# %%
# combining the conditions for the data frame

# %%
titanic.head(1)
# Out:
#    pclass  survived                           name     sex age  sibsp  parch  \
# 0       1         1  Allen, Miss. Elisabeth Walton  female  29      0      0
#
#   ticket      fare cabin embarked boat body     home.dest
# 0  24160  211.3375    B5        S    2    ?  St Louis, MO

# %%
women = titanic['sex']=='female'
died = titanic['survived']==0

# %%
test_condition= women & died

# %%
titanic[test_condition]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 105        1         0                           Evans, Miss. Edith Corse
# 169        1         0                         Isham, Miss. Ann Elizabeth
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# ...      ...       ...                                                ...
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses[houses['waterfront']==1]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 264    2123039032  20141027T000000   369900.0         1       0.75
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# ...           ...              ...        ...       ...        ...
# 19984  2025069140  20150317T000000  1898000.0         3       2.50
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %%
'''
Important thing to notice here is that parenthesis 
houses[houses['waterfront']==1 & houses['price']<=55000]-> this will give out error cause it will try to and 1 and houses['Price']
'''
houses[(houses['waterfront']==1) & (houses['price']<=500000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 264    2123039032  20141027T000000  369900.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 1949   1922039062  20150420T000000  480000.0         2       1.50
# 3829   8550001515  20141001T000000  429592.0         2       2.75
# 6102    222029026  20140917T000000  340000.0         2       0.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 13525  2013802060  20140927T000000  500000.0         2       1.00
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 16570  2923039243  20141113T000000  340000.0         4       1.00
# 18275  2781600195  20141117T000000  285000.0         1       1.00
# 18848  7631800110  20140918T000000  380000.0         3       2.50
# ...

# %% [markdown]
# ~ can be use to negate the True and False data Series so is quiet useful

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8807 non-null   int64
#  1   show_id       8807 non-null   object
#  2   type          8807 non-null   object
#  3   title         8807 non-null   object
#  4   director      6173 non-null   object
#  5   cast          7982 non-null   object
#  6   country       7976 non-null   object
#  7   date_added    8797 non-null   object
#  8   release_year  8807 non-null   int64
#  9   rating        8803 non-null   object
#  10  duration      8804 non-null   object
#  11  listed_in     8807 non-null   object
#  12  description   8807 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %%
netflix["director"].isna()# gives True if NaN is present
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: director, Length: 8807, dtype: bool

# %%
netflix.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
netflix.director.notna()
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806     True
# Name: director, Length: 8807, dtype: bool

# %%
~netflix.director.isna()# notna and isna are opposite of each other
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806     True
# Name: director, Length: 8807, dtype: bool
